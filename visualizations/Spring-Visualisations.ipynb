# %%
from pandas import json_normalize
import pandas as pd

# %%
df = pd.read_json('../simulations/springSimulation.json')

# %%
normal = json_normalize(df["Location"])

# %%
import matplotlib.pyplot as plt
normal["x"]
# Out:
# 0         0.000000
# 1         0.050000
# 2         0.100000
# 3         0.150000
# 4         0.199999
#            ...
# 29996   -35.888065
# 29997   -35.887578
# 29998   -35.887019
# 29999   -35.886389
# 30000   -35.885687
# Name: x, Length: 30001, dtype: float64

# %%
plt.plot(df["Time"],normal['x'])
