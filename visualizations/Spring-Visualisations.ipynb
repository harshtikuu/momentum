# %%
from pandas import json_normalize
import pandas as pd

# %%
df = pd.read_json('../simulations/springSimulation.json');

# %%
normal = json_normalize(df["Location"])

# %%
import matplotlib.pyplot as plt
normal["x"]
# Out:
# 0       0.000000
# 1       0.166667
# 2       0.333310
# 3       0.499884
# 4       0.666343
#           ...
# 2996   -4.033376
# 2997   -3.839208
# 2998   -3.643947
# 2999   -3.447646
# 3000   -3.250360
# Name: x, Length: 3001, dtype: float64

# %%
plt.plot(normal["x"],df["Time"])

# %%
import numpy as np
x = np.linspace(-10,10);
y = np.sin(x)
plt.plot(x,y)
